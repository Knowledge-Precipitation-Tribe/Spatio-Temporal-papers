# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_table("./data/meta.txt")
data.head(50)
# Out:
#         ID  Fwy Dir  District  County     City State_PM   Abs_PM   Latitude  \
# 0   715898    5   S         7      37  40032.0      .71  117.280  33.880183
# 1   715900    5   S         7      37  40032.0     1.06  117.630  33.882892
# 2   715901    5   N         7      37  40032.0     1.11  117.743  33.883400
# 3   715903    5   N         7      37  69154.0     1.56  118.193  33.886992
# 4   715906    5   S         7      37  52526.0     3.28  119.850  33.900669
# 5   715907    5   S         7      37  52526.0     3.62  120.190  33.903961
# 6   715908    5   S         7      37  52526.0     4.28  120.850  33.911074
# 7   715910    5   N         7      37  52526.0     4.58  121.213  33.913564
# 8   715913    5   S         7      37  52526.0     5.22  121.790  33.920763
# 9   715918    5   N         7      37  52526.0      6.2  122.833  33.933110
# 10  715920    5   S         7      37  52526.0     6.64  123.210  33.938544
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4801 entries, 0 to 4800
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         4801 non-null   int64
#  1   Fwy        4801 non-null   int64
#  2   Dir        4801 non-null   object
#  3   District   4801 non-null   int64
#  4   County     4801 non-null   int64
#  5   City       4310 non-null   float64
#  6   State_PM   4801 non-null   object
#  7   Abs_PM     4801 non-null   float64
#  8   Latitude   4796 non-null   float64
#  9   Longitude  4796 non-null   float64
#  10  Length     2717 non-null   float64
#  11  Type       4801 non-null   object
#  12  Lanes      4801 non-null   int64
#  13  Name       4801 non-null   object
#  14  User_ID_1  4801 non-null   int64
#  15  User_ID_2  0 non-null      float64
#  16  User_ID_3  0 non-null      float64
#  17  User_ID_4  0 non-null      float64
# dtypes: float64(8), int64(6), object(4)
# ...

# %%
data.describe()
# Out:
#                   ID          Fwy  District       County         City  \
# count    4801.000000  4801.000000    4801.0  4801.000000   4310.00000
# mean   745982.981879   177.959592       7.0    41.099979  41699.29420
# std     25156.901035   194.351865       0.0    16.930692  19758.70544
# min    715898.000000     2.000000       7.0    37.000000    394.00000
# 25%    717374.000000    14.000000       7.0    37.000000  32548.00000
# 50%    761149.000000   105.000000       7.0    37.000000  44000.00000
# 75%    768304.000000   210.000000       7.0    37.000000  48648.00000
# max    775774.000000   710.000000       7.0   111.000000  90310.00000
#
#             Abs_PM     Latitude    Longitude       Length        Lanes  \
# count  4801.000000  4796.000000  4796.000000  2717.000000  4801.000000
# mean     34.609625    34.066205  -118.240227     0.607464     2.287648
# std      39.331907     0.145792     0.257796     0.556273     1.534449
# ...

# %%
data.shape
# Out:
# (4801, 18)

# %%
data.tail()
# Out:
#           ID  Fwy Dir  District  County     City State_PM  Abs_PM   Latitude  \
# 4796  775752  110   S         7      37  44000.0    R1.58   1.580  33.758642
# 4797  775762   47   S         7      37  44000.0       R0   0.234  33.748932
# 4798  775763   47   S         7      37  44000.0       R0   0.234  33.748932
# 4799  775773  110   N         7      37  44000.0     2.65   2.580  33.770321
# 4800  775774  110   S         7      37  44000.0     2.65   2.580  33.770329
#
#        Longitude  Length Type  Lanes               Name  User_ID_1  User_ID_2  \
# 4796 -118.289784   2.080   ML      4          JS GIBSON       3829        NaN
# 4797 -118.290236   0.200   ML      2   CONNECTOR TO 110       2564        NaN
# 4798 -118.290236   0.234   ML      3   CONNECTOR TO 110       2564        NaN
# 4799 -118.280319   0.595   ML      4  S/O HARRY BRIDGES       3837        NaN
# 4800 -118.280609   3.000   ML      4  S/O HARRY BRIDGES       3837        NaN
#
#       User_ID_3  User_ID_4
# ...

# %%
data.to_csv("metadata.csv")
